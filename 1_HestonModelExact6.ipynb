# %% [markdown]
# # Exact Heston Model Simulations for Characteristic Function Methods

# %%
# Import all functions from utils to avoid code duplication
from utils import *

# %% [markdown]
# For the implementation of COS, Carr-Madan, CONV methods, CDF_Inverter function, and generateHestonPaths please refer to the utils.py file.

# %%
if __name__ == "__main__":
    # Parameters
    NoOfPaths = 4
    NoOfSteps = 50

    
    # Heston model parameters
    gamma = 0.4 # vol of vol
    kappa = 0.5 # speed of mean reversion
    vbar = 0.2 # long-term mean
    rho = -0.9 # negative correlation
    v0 = 0.2 # initial variance
    T = 1.0
    S_0 = 100.0
    r = 0.1
    
    nr_expansion = 100
    L = 10
    
    # Set random seed for reproducibility
    np.random.seed(3)
    
    # Test all three methods
    methods_to_test = {
        "cos": {},
        "carr_madan": {"N": 2**12},
        "conv": {"alpha": 0.5, "N": 2**13}
    }
    
    results = {}
    
    for method_name, kwargs in methods_to_test.items():
        print(f"\n=== Testing {method_name.upper()} Method ===")
        
        # Reset random seed to ensure fair comparison
        np.random.seed(3)
        
        start_time = time.time()
        paths = GeneratePathsHestonES(
            NoOfPaths, NoOfSteps, T, r, S_0, kappa, gamma, rho, vbar, v0,
            nr_expansion=nr_expansion, L=L, recovery_method=method_name, **kwargs
        )
        end_time = time.time()
        
        results[method_name] = {
            "paths": paths,
            "computation_time": end_time - start_time
        }
        
        # Check for zeros in integrated variance
        V_int = paths["Vint"]
        min_vint = np.min(V_int)
        zero_count = np.sum(V_int <= 1e-10)
        
        print(f"Computation time: {end_time - start_time:.3f} seconds")
        print(f"Min integrated variance: {min_vint:.8f}")
        print(f"Values <= 1e-10: {zero_count}/{V_int.size}")
        print(f"All positive: {np.all(V_int > 0)}")
    
    # Plot comparison
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    
    for idx, (method_name, result) in enumerate(results.items()):
        timeGrid = result["paths"]["time"]
        S = result["paths"]["S"]
        V_int = result["paths"]["Vint"]
        
        # Plot integrated variance
        axes[0, idx].grid(True)
        axes[0, idx].plot(timeGrid, np.transpose(V_int))
        axes[0, idx].set_xlabel('Time')
        axes[0, idx].set_ylabel(r'$\int_0^t V_s ds$')
        axes[0, idx].set_title(f'{method_name.upper()}: Integrated Variance\nTime: {result["computation_time"]:.3f}s')
        
        # Add text showing min value and zero count
        min_val = np.min(V_int)
        zero_count = np.sum(V_int <= 1e-10)
        axes[0, idx].text(0.05, 0.95, f'Min: {min_val:.2e}\nZeros: {zero_count}', 
                         transform=axes[0, idx].transAxes, verticalalignment='top',
                         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
        
        # Plot stock price paths
        axes[1, idx].grid(True)
        axes[1, idx].plot(timeGrid, np.transpose(S))
        axes[1, idx].set_xlabel('Time')
        axes[1, idx].set_ylabel(r'$S_t$')
        axes[1, idx].set_title(f'{method_name.upper()}: Stock Prices')
    
    plt.tight_layout()
    plt.show()
    
    # Print timing comparison
    print("\n=== Performance Comparison ===")
    for method_name, result in results.items():
        print(f"{method_name.upper()}: {result['computation_time']:.3f} seconds")
    
    # Print zero analysis
    print("\n=== Zero Analysis ===")
    for method_name, result in results.items():
        V_int = result["paths"]["Vint"]
        min_val = np.min(V_int)
        zero_count = np.sum(V_int <= 1e-10)
        exact_zero_count = np.sum(V_int == 0.0)
        print(f"{method_name.upper()}: min={min_val:.8f}, zeros(<=1e-10)={zero_count}, exact_zeros={exact_zero_count}")
# Out:
# === Testing COS Method ===
# Using cos method for CDF recovery and inversion
# Computation time: 0.118 seconds
# Min integrated variance: 0.00004607
# Values <= 1e-10: 0/204
# All positive: True
#
# === Testing CARR_MADAN Method ===
# Using carr_madan method for CDF recovery and inversion
# Computation time: 2.626 seconds
# Min integrated variance: 0.00003260
# Values <= 1e-10: 0/204
# All positive: True
#
# === Testing CONV Method ===
# Using conv method for CDF recovery and inversion
# Computation time: 5.316 seconds
# Min integrated variance: 0.00004613
# Values <= 1e-10: 0/204
# All positive: True
# === Performance Comparison ===
# COS: 0.118 seconds
# CARR_MADAN: 2.626 seconds
# CONV: 5.316 seconds
#
# === Zero Analysis ===
# COS: min=0.00004607, zeros(<=1e-10)=0, exact_zeros=0
# CARR_MADAN: min=0.00003260, zeros(<=1e-10)=0, exact_zeros=0
# CONV: min=0.00004613, zeros(<=1e-10)=0, exact_zeros=0

# %%
np.random.seed(19937)
paths = GeneratePathsHestonES(
    NoOfPaths=3, NoOfSteps=10, T=0.5, r=0.05, S_0=100,
    kappa=0.5, gamma=0.4, rho=-0.7, vbar=0.2, v0=0.2,
    nr_expansion=50, L=8, recovery_method='carr_madan', N=2048
)

min_vint = np.min(paths['Vint'])
zero_count = np.sum(paths['Vint'] < 1e-10)
print(f"Min integrated variance: {min_vint:.8f}")
print(f"Zero values: {zero_count}/{paths['Vint'].size}")
print(f"All values positive: {np.all(paths['Vint'] > 0)}")

# Show first few values
print(f"First few values: {paths['Vint'][:, :5]}")

# If we still see zeros, there's a problem with the import
if zero_count > 0:
    print("❌ ERROR: Still seeing zeros! The fixed utils.py is not being used.")
    print("Please restart the Jupyter kernel and run all cells again.")
else:
    print("✅ SUCCESS: No zeros found! The fix is working correctly.")
# Out:
# Using carr_madan method for CDF recovery and inversion
# Min integrated variance: 0.00182540
# Zero values: 0/33
# All values positive: True
# First few values: [[0.01       0.00820748 0.01244002 0.0057766  0.00594043]
#  [0.01       0.01216596 0.00488744 0.00421276 0.00721748]
#  [0.01       0.01324573 0.00684683 0.00610532 0.01005199]]
# ✅ SUCCESS: No zeros found! The fix is working correctly.

# %% [markdown]
# ## Observations
# 1 Comparison:
# - COS method is the fastest - avoids using integration, most stable.
# - Carr-Madan method seems unstable due to stability issues likely due to very small values when inverting CDF.
# - CONV method is the slowest due to expensive convolution operations.
#
# 2 Stock Prices:
# - Each method produces similar final stock trajectories
#
# 3 Integrated variance process hits zeros for Carr-Madan method
#
# - compute_pdf() - returns small value for derivated, so Newton's step collapses to 0.
#
# - compute_cdf() - may be non-monotone or "too flat" near 0, so the best initial guess is (at/near) 0.
#
# - COS and CONV methods have built-in numerical stabilization mechanisms that prevent PDFs from getting too close to zero, while Carr-Madan is more susceptible to producing extreme values that break Newton's method.
#
# - This explains why only Carr-Madan causes the integrated variance to hit zero - its PDF can become numerically zero, making Newton's method unstable, which cascades into the path simulation hitting boundary conditions.
#
# 3

# %% [markdown]
# ## Comparison

# %% [markdown]
# #### COS method is the winner
# Use cases:
# - Option Pricing: replacing the Monte Carlo with COS method.
# - Model Calibration: Can be used to fit Heston parameters.
# - Trading Systems: Enables fast Greeks and sensitivity analysis.
# - Real-time Risk Management: Very fast calculations of VaR.

# %% [markdown]
# #### Newton-Raphson method vs. brute force approach for CDF inversion

# %%
compare_cdf_inversion_methods()
# Out:
# /Users/patrikliba/QFB/utils.py:638: RuntimeWarning: invalid value encountered in scalar multiply
#   chf = temp1 * temp2 * temp3 / temp4
# /Users/patrikliba/QFB/utils.py:638: RuntimeWarning: invalid value encountered in scalar divide
#   chf = temp1 * temp2 * temp3 / temp4
# /Users/patrikliba/QFB/utils.py:625: RuntimeWarning: invalid value encountered in divide
#   temp1 = R * np.exp(-tau / 2.0 * (R - kappa)) * (1 - np.exp(-kappa * tau)) / (kappa * (1 - np.exp(-R * tau)))
# /Users/patrikliba/QFB/utils.py:628: RuntimeWarning: invalid value encountered in divide
#   kappa * (1 + np.exp(-kappa * tau)) / (1 - np.exp(-kappa * tau)) - R * (1 + np.exp(-R * tau)) / (
# /Users/patrikliba/QFB/utils.py:633: RuntimeWarning: invalid value encountered in divide
#   np.sqrt(vt * vu) * 4.0 * R * np.exp(-R * tau / 2.0) / (gamma ** 2 * (1 - np.exp(-R * tau))))
#     N  Brute Time (s)  Newton Time (s)  vint_brute_values  vint_newton_values
# 0   4        1.050631         0.043488           0.003782            0.003759
# 1   8        2.154413         0.079584           0.002805            0.002788
# 2  16        4.156240         0.161021           0.003679            0.003659
# 3  32        8.201021         0.324437           0.003089            0.003083
# 4  64       16.853259         0.635697                NaN            0.003533
